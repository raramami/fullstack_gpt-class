# %%
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import TextLoader, UnstructuredFileLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter,CharacterTextSplitter

# splitter = RecursiveCharacterTextSplitter(
#     chunk_size = 200,
#     chunk_overlap = 50,
# )

# https://platform.openai.com/tokenizer
splitter = CharacterTextSplitter.from_tiktoken_encoder(  #AI model 이 이해하는 토큰 방식을 사용해서 
    separator="\n\n",
    chunk_size = 600,
    chunk_overlap = 50,

)


loader = UnstructuredFileLoader("./files/it_infra.pptx")

loader.load_and_split(text_splitter=splitter)

#len(loader.load_and_split(text_splitter=splitter))   #document 수 확인
# Out:
# [Document(page_content='IT 인프라 유지보수 연장을 위한 Vendor Information Screening\n\n비즈니스 연속성을 위한 벤더 신뢰성 검증 프레임워크\n\n2026-01-29\n\n작성: IT 운영 · 보안 · 조달 공동\n\nVIS의 목적과 중요성\n\n유지보수의 필요성과 미실시 리스크를 명확히 제시하여 연장 의사결정의 설득력 강화\n\n목적\n\n유지보수 필요성\n\n유지보수 연장 전 벤더의 신뢰성·보안·준법·재무·성과를 체계적으로 검증\n\n보안 패치·업데이트, 노후 HW 교체, 규제·감사 대응, 라이선스 갱신, 장애 예방·가용성 보장\n\nIT 인프라 특성\n\n검증 범위', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='IT 인프라 특성\n\n검증 범위\n\n서버·네트워크·클라우드의 상호의존성으로 단일 장애가 전체 서비스로 전파\n\n사이버보안(인증·취약점), 계약 준수, 재무 건전성, 과거 성과(SLA·MTTR), 공급망\n\n미실시 리스크\n\n기대 효과\n\n장기 다운타임·데이터 유출·규제 벌금·SLA 위반·복구비용 급증·평판 훼손\n\n중단·보안사고 리스크 감소, 비용 대비 성과 최적화, 비즈니스 연속성 확보\n\nIT 인프라 리소스 현황 다이어그램\n\n3계층(서버 · 네트워크 · 시설/보호) 기준으로 리소스와 연결 관계를 시각화\n\n서버\n\n네트워크\n\n시설·보호', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='서버\n\n네트워크\n\n시설·보호\n\n물리서버 5대\n\n가상서버 9대\n\n테스트 4대\n\nTomcat\n\nNginx\n\nSQL\n\nDeveloper\n\n파일\n\nHost1\n\nHost2\n\n도메인\n\nSQL\n\n서버 계층\n\n운영 4대\n\nTomcat\n\nNginx\n\nIIS\n\nFTP\n\nHost1 ↔ Host2: Hyper-Clustering (Failover)\n\n참고: 총 9대 구성(상세 8대 + 기타 1대)\n\n가상화 클러스터로 구성되어 장애 시 상호 Failover 지원\n\n무선 컨트롤러 ×1\n\n백본 SW ×2\n\n워크그룹 SW ×6\n\n무선 AP ×6\n\n네트워크 계층\n\n테이프 장치\n\nUPS\n\n스토리지\n\n전기·방재 설비\n\n서버실\n\n시설/보호 계층\n\n연결 관계\n\n데이터 경로\n\n백업 경로\n\n전원 경로\n\n서버 ↔ 백본 스위치 ↔ 워크그룹 스위치 ↔ 무선 AP\n\n서버 → 스토리지 / 테이프 장치', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='서버 → 스토리지 / 테이프 장치\n\n상용전원 → UPS → 서버·네트워크 장비\n\n참고: 수량 및 구성은 요청 정보 기준. 실제 환경 다이어그램에 맞게 장비명/연결을 상세화하세요.\n\n벤더 정보 · 재무(최근 2년) · 레퍼런스\n\n3개 벤더의 프로필·역량과 최근 2년 재무(매출·영업이익), 레퍼런스/링크를 비교\n\nADDITS\n\nKDDI Korea\n\n대신NS\n\n프로필\n\n프로필\n\n프로필\n\n시스템 통합·유지보수, 서버/스토리지, 네트워크, 시스템 솔루션\n\n데이터센터(Seoul VIDC), 클라우드/SaaS/네트워크\n\n네트워크·보안, 서버 시스템, 정보통신·전기공사', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='운영 아웃소싱 및 글로벌 지원\n\n구축부터 유지보수까지 전국 지원\n\n기업 시스템 개발 및 맞춤형 IT 서비스\n\n핵심 역량\n\n핵심 역량\n\n핵심 역량\n\n코로케이션+네트워크 번들 제공\n\n현장 대응력, 통신·전기 통합 구축 역량\n\nSI–유지보수 원스톱 제공\n\n글로벌 커버리지·엔터프라이즈 운영 노하우\n\n지역 커버리지 및 빠른 복구 지원\n\n멀티벤더 지원·통합 운영 역량\n\n재무(최근 2년)\n\n재무(최근 2년)\n\n재무(최근 2년)\n\n매출(2024–2025): {케이디디아이코리아 공식 공시 확인 필요}\n\n매출(2024–2025): {공식 재무제표 제출 필요}', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='매출(2024–2025): {공식 재무제표 제출 필요}\n\n매출(2024–2025): {공식 재무제표 제출 필요}\n\n영업이익(2024–2025): {케이디디아이코리아 공식 공시 확인 필요}\n\n영업이익(2024–2025): {공식 재무제표 제출 필요}\n\n영업이익(2024–2025): {공식 재무제표 제출 필요}\n\n레퍼런스/링크\n\n레퍼런스/링크\n\n레퍼런스/링크\n\n공식: kr.kddi.com\n\n공식 홈페이지: ds-ns.net\n\n공식 홈페이지: addits.co.kr\n\n재무 정보: kr.kddi.com/ko/company/financial/\n\n고객사/프로젝트 레퍼런스: {벤더 제출 필요}\n\n고객사/프로젝트 레퍼런스: {벤더 제출 필요}\n\n고객사/프로젝트 레퍼런스: {벤더 제출 필요}', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='요청 자료: 기술인력·파트너, 지역별 SLA/MTTA·MTTR, 안전·전기 인증, 예방점검 계획\n\n요청 자료: 보안정책·인증, 1–2년 SLA/장애 이력, 재무제표·보험증권, 유사 사례\n\n요청 자료: DC/보안 인증, 가용성·DR 설계, 감사·펜테스트 결과, 서비스 카탈로그\n\n출처: ds-ns.net\n\n출처: addits.co.kr\n\n출처: kr.kddi.com\n\n참고: 재무 수치는 벤더의 공식 재무제표(감사/검토보고서)로 확인해야 합니다. 공개 링크는 확인 편의용이며, 실제 계약 심사에는 원본 문서를 제출받아 검증하세요.\n\n벤더 평가 매트릭스 및 선정', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='벤더 평가 매트릭스 및 선정\n\n평가 항목·가중치: 기술역량 20%, 재무안정성 15%, 보안준수 20%, 성능이력 15%, 가격경쟁력 20%, 대응력 10% — 예시 점수로 총점 계산\n\n평가표(예시 점수, 10점 만점)\n\n역량 비교 레이더 차트(예시)\n\n가중치 적용 총점 기준 비교\n\n축: 0–10', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='가중치 적용 총점 기준 비교\n\n축: 0–10\n\n항목                     가중치      ADDITS    KDDI Korea    대신NS\n기술역량                 20%            8             8.5       7.5\n재무안정성               15%            7             8         6.5\n보안준수                 20%            7.5           8.5       7\n성능이력                 15%            7.5           8         7\n가격경쟁력               20%            8             7         8.5\n대응력                   10%            8.5           7.5       8\n가중합 총점(100점 환산)  —             77.3          79.5      74.3\n\n최종 선정', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='최종 선정\n\n주: 위 점수와 총점은 예시입니다. 실제 선정 시 내부 평가위원 합의에 따라 점수와 가중치를 조정하세요.\n\n{XX 업체}\n\n예시 총점 기준 최고점: KDDI Korea 79.5 / 100\n\n표기된 {XX 업체}는 발표용 자리표시자입니다. 실제 의사결정 확정 후 교체하세요.\n\n검증 메모: 벤더 자체 제출 자료(보안·재무·성능) 교차검증 필요. 평가 근거와 가중치 변경 사항은 회의록으로 보관하세요.\n\n주간 KPI 및 성능 리뷰 시각화(예시)', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='주간 KPI 및 성능 리뷰 시각화(예시)\n\n주간 체크리스트 기반 성과 지표(최근 4주): SLA, 응답/복구시간, 장애 건수, 패치·백업 준수율, 체크리스트 준수율\n\nSLA · 평균 응답시간 · MTTR (최근 4주)\n\n주간 장애 건수(하드웨어/네트워크/소프트웨어/보안)\n\n패치·백업 준수율(최근 주)\n\n주간 체크리스트 준수 현황(최근 주)\n\n목표 ≥ 95%', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='목표 ≥ 95%\n\n항목       설명                     준수율\n백업 검증  복구 테스트·무결성 확인  100%\n로그 점검  보안·시스템 로그 리뷰    98%\n패치 적용  OS/펌웨어·소프트웨어     95%\n자산 점검  구성·라이선스·보호상태   99%\nDR 테스트  복구 시나리오 점검       96%\n\n패치\n\n백업\n\n95%\n\n99%\n\n참고: 수치는 예시입니다. 실제 주간 점검 데이터로 업데이트하세요.\n\n대시보드 데이터(최근 4주): SLA 99.7/99.9/99.8/100.0%, 응답 18/16/14/12분, MTTR 74/68/55/49분, 장애 HW 1/0/1/0, NW 2/1/1/0, SW 1/2/1/1, SEC 0/0/1/0\n\n준비해야 할 주요 자료 목록 (5개 항목)', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='준비해야 할 주요 자료 목록 (5개 항목)\n\nIT 인프라 유지보수 연장에 필요한 문서를 카드 형식으로 정리\n\n벤더 기본 정보·프로필\n\n보안 및 준법 준수\n\n성능 및 계약 이력\n\n회사명·주소·연락처·설립연도·사업영역\n\n보안 정책·데이터 보호(ISO 27001, GDPR 등)\n\nSLA 준수율·응답시간·다운타임 지표\n\nIT 인프라 유지보수 경험·유사 프로젝트\n\n취약점 평가·최근 감사 결과\n\n모니터링 데이터·HW 교체 기록\n\nIRS TIN 매칭·W-9 검증(해당 시)\n\n제3자/하청 보안 수준 확인\n\n반기별 성능 리뷰 결과\n\n재무 및 위험 평가\n\n기타 지원 문서', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='재무 및 위험 평가\n\n기타 지원 문서\n\n최근 1–2년 재무제표·신용등급\n\n라이선스·인증(Microsoft 파트너 등) 사본\n\n보험 증명서·계약 이행 보증\n\n기존 계약서, SOW, 부속서\n\n공급망/하청 리스크 체크리스트\n\n소프트웨어 호환성·사이버 보안 체크리스트\n\nVIS 자료 준비 단계별 가이드 (5단계)\n\n타임라인 형식으로 각 단계의 주요 활동과 산출물을 명확히 정리\n\n1\n\n2\n\n3\n\n4\n\n5\n\n초기 평가\n\n자료 수집\n\n위험 분석\n\n검토·업데이트\n\n보관·모니터링\n\n초기 평가 및 요구사항 확인\n\n자료 수집 및 검증\n\n위험 분석 및 보고서 작성\n\n검토 및 업데이트', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='검토 및 업데이트\n\n보관 및 모니터링\n\n활동: 내부 정책·법규 검토, 항목 정의, 자료요청 양식 발송\n\n활동: 문서 수령·진위 확인, 인증·보고서 검증, TIN 매칭·최신성 확인(2026)\n\n활동: 보안 점수화, 취약점·완화대책, 재무·공급망 리스크 평가\n\n활동: IT·법무·재무 합의, KPI 정의(SLA·응답시간), 리뷰 계획\n\n활동: 중앙 VMS 보관, 업데이트 주기, 성과 모니터링\n\n산출물: 요구사항 정의서, 자료요청서\n\n산출물: 위험평가 보고서, 연장 권고안\n\n산출물: 합의 메모, KPI 부속서\n\n산출물: 저장 경로, 모니터링 캘린더\n\n산출물: 검증 체크리스트', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='산출물: 검증 체크리스트\n\n참고: 각 단계는 조직의 벤더 관리 정책에 맞추어 조정 가능합니다.\n\n마무리: 핵심 메시지와 다음 단계\n\nVIS 결과를 바탕으로 연장 의사결정의 신뢰성과 속도를 높입니다\n\n핵심 메시지\n\n다음 단계 일정\n\nVIS는 보안·준법·성능·재무를 균형 있게 평가하여 리스크를 최소화하고, IT 인프라 유지보수 연장의 타당성을 객관적으로 입증합니다.\n\n자료요청 발송\n\n오늘\n\n수집 2주\n\n분석 1주\n\n의사결정 회의\n\n기대 효과\n\n서비스 안정성 강화와 중단 리스크 감소\n\n비용 대비 성과 최적화 및 KPI 기반 관리', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='비용 대비 성과 최적화 및 KPI 기반 관리\n\n실행 체계\n\n규제 대응 및 감사 준비도 향상\n\n평가 책임자 지정 및 역할·권한 명확화\n\n데이터룸(VMS) 생성 및 문서 버전 관리\n\n표준 평가 체크리스트 배포\n\n문의\n\n프로젝트 PM / 보안 책임자 / 조달 담당\n\n참고: 일정 및 역할은 조직의 벤더 관리 정책과 프로젝트 규모에 맞게 조정하세요.\n\n경영진 고정비 삭감 요청 대응: 유지보수 연장 경제성 입증\n\n숨겨진 비용(Hidden Cost) 정량화 + TCO 시나리오 비교(현행 유지 vs 중단 vs 인하우스)\n\n시나리오별 1년 TCO 비교(예시)\n\n유지보수 중단 시 숨겨진 비용(Hidden Cost)', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='유지보수 중단 시 숨겨진 비용(Hidden Cost)\n\n단위: 백만원 · 실제 수치로 교체 필요\n\n긴급 복구비·시간외 인건비\n\n매출 손실(다운타임 × 시간당 매출)\n\n규제 벌금·계약 벌칙(SLA 페널티)\n\n데이터 복구·포렌식 비용\n\n평판 훼손에 따른 고객 이탈\n\n경영진 보고를 위한 필요 자료와 예시\n\n다운타임 비용 모델: 시간당 매출 {입력} × 예상 다운타임 {입력}시간\n\nSLA 위반 페널티: 계약 부속서의 벌칙 조항 발췌\n\nTCO 구성요소(예시)\n\n보안·규제 리스크: 최근 감사/취약점 평가 보고서 요약', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='구성요소                    현행 유지    중단    인하우스\n계약비(정기 유지보수)              70       0          40\n긴급복구·다운타임                  10     110          50\n인력·도구(모니터링/백업)           20      50          40\n합계(예시)                        100     160         130\n\nDR/백업 지표: RTO/RPO 목표와 최근 복구 테스트 결과\n\n인력·도구 비용: 인하우스 전환 시 채용·교육·툴 라이선스 견적\n\n결론(예시)', metadata={'source': './files/it_infra.pptx'}),
#  Document(page_content='결론(예시)\n\n예시 기준으로 현행 유지의 1년 TCO가 가장 낮아 유지보수 연장이 경제적으로 타당합니다. 실제 수치로 교체하여 최종 결정 근거로 사용하세요.\n\n주: 예시 수치입니다. 실제 견적/내부 비용 데이터를 반영하세요.\n\n참고: 본 페이지의 수치는 설명용 예시입니다. 견적서·계약서·내부 재무 데이터로 검증 후 최종안을 확정하세요.', metadata={'source': './files/it_infra.pptx'})]
