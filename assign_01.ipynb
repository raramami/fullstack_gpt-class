# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(temperature=0.1,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()]
)

haiku_prompt = ChatPromptTemplate.from_messages([
    ("system","You are a specialized in writing poem about programming languages. Pls make Korean Poem with 5-7-5 formatting."),
    ("human","{language}"),
])

haiku_chain = haiku_prompt | chat 



explanation_prompt = ChatPromptTemplate.from_messages([
    ("system","You are an veteran programmer and poem critics. Pls read the poem , and kindly explain technical meaning and programming language feature about it."),
    ("human","{haiku}")
]
)

exp_chain = explanation_prompt | chat 

final_chain = {"haiku":haiku_chain} | exp_chain 

final_chain.invoke({
    "language":"javascript",
})
# Out:
# 자바스크립트야
# 동적이고 유연한
# 웹을 빛내네This poem seems to be written in Korean and talks about JavaScript, describing it as dynamic and flexible, bringing light to the web.
#
# From a technical perspective, the poem mentions some key characteristics of JavaScript:
#
# 1. Dynamic: JavaScript is known for being a dynamic language, meaning that variables do not have a fixed data type. This allows for flexibility in coding and makes it easier to work with different types of data.
#
# 2. Flexible: JavaScript is a versatile language that can be used for a wide range of tasks, from simple web interactions to complex web applications. Its flexibility allows developers to create interactive and engaging websites.
#
# 3. Bringing light to the web: JavaScript is often used to enhance the user experience on websites by adding interactive elements, animations, and dynamic content. It plays a crucial role in making the web more engaging and user-friendly.
#
# ...
